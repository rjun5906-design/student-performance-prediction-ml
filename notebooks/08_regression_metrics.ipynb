# %%
from src.evaluate_models import eval_reg

results = eval_reg(
    [1, 2, 3, 4],
    [1, 2, 3, 5]
)

print(results)
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[3], line 1
# ----> 1 from src.evaluate_models import eval_reg
#       3 results = eval_reg(
#       4     [1, 2, 3, 4],
#       5     [1, 2, 3, 5]
#       6 )
#       8 print(results)
#
# ModuleNotFoundError: No module named 'src'
