# %%
import sys
from pathlib import Path

project_root = Path.cwd().parent
sys.path.insert(0, str(project_root))

# %%
from src.evaluate_models import eval_reg

results = eval_reg(
    [1, 2, 3, 4],
    [1, 2, 3, 5]
)

print(results)
# Out:
# {'MAE': 0.25, 'RMSE': 0.5, 'R2': 0.8}
