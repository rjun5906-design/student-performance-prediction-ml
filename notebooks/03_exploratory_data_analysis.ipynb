# %%
import os

for root, dirs, files in os.walk("./data"):
    for file in files:
        if file.endswith(".csv"):
            print(os.path.join(root, file))

# %%
import os

print("Current working directory:")
print(os.getcwd())

print("\nFiles and folders here:")
print(os.listdir())
# Out:
# Current working directory:
# /Users/jjun28/Desktop/Github 2026/student-performance-prediction-ml/notebooks
#
# Files and folders here:
# ['03_exploratory_data_analysis.ipynb', '01_data_understanding.ipynb', '.gitkeep', '02_data_cleaning_preprocessing.ipynb', 'figures', '00_environment.ipynb']

# %%
import os

for root, dirs, files in os.walk("."):
    for file in files:
        if file.endswith(".csv"):
            print(os.path.join(root, file))

# %%
df = pd.read_csv("../data/student-mat.csv", sep=";")

# %%
import pandas as pd

df = pd.read_csv("../data/student-mat.csv", sep=";")

print(df.shape)
df.head()
# Out:
# (395, 33)
#   school sex  age address famsize Pstatus  Medu  Fedu     Mjob      Fjob  ...  \
# 0     GP   F   18       U     GT3       A     4     4  at_home   teacher  ...
# 1     GP   F   17       U     GT3       T     1     1  at_home     other  ...
# 2     GP   F   15       U     LE3       T     1     1  at_home     other  ...
# 3     GP   F   15       U     GT3       T     4     2   health  services  ...
# 4     GP   F   16       U     GT3       T     3     3    other     other  ...
#
#   famrel freetime  goout  Dalc  Walc health absences  G1  G2  G3
# 0      4        3      4     1     1      3        6   5   6   6
# 1      5        3      3     1     1      3        4   5   5   6
# 2      4        3      2     2     3      3       10   7   8  10
# 3      3        2      2     1     1      5        2  15  14  15
# 4      4        3      2     1     2      5        4   6  10  10
#
# [5 rows x 33 columns]

# %%
num_cols = df.select_dtypes(include="number").columns.tolist()

numeric_summary = (
    df[num_cols]
    .agg(["min", "max", "mean"])
    .T
    .round(2)
)

display(numeric_summary)
# Out:
#              min   max   mean
# age         15.0  22.0  16.70
# Medu         0.0   4.0   2.75
# Fedu         0.0   4.0   2.52
# traveltime   1.0   4.0   1.45
# studytime    1.0   4.0   2.04
# failures     0.0   3.0   0.33
# famrel       1.0   5.0   3.94
# freetime     1.0   5.0   3.24
# goout        1.0   5.0   3.11
# Dalc         1.0   5.0   1.48
# Walc         1.0   5.0   2.29
# health       1.0   5.0   3.55
# absences     0.0  75.0   5.71
# G1           3.0  19.0  10.91
# G2           0.0  19.0  10.71
# G3           0.0  20.0  10.42

# %%
import os

os.makedirs("../reports", exist_ok=True)

numeric_summary.to_csv(
    "../reports/session12_numeric_summary.csv"
)

print("Saved Session 12 numeric summary.")
# Out:
# Saved Session 12 numeric summary.

# %%
num_cols = df.select_dtypes(include="number").columns.tolist()

numeric_summary = (
    df[num_cols]
    .agg(["min", "max", "mean"])
    .T
    .round(2)
)

display(numeric_summary)
# Out:
#              min   max   mean
# age         15.0  22.0  16.70
# Medu         0.0   4.0   2.75
# Fedu         0.0   4.0   2.52
# traveltime   1.0   4.0   1.45
# studytime    1.0   4.0   2.04
# failures     0.0   3.0   0.33
# famrel       1.0   5.0   3.94
# freetime     1.0   5.0   3.24
# goout        1.0   5.0   3.11
# Dalc         1.0   5.0   1.48
# Walc         1.0   5.0   2.29
# health       1.0   5.0   3.55
# absences     0.0  75.0   5.71
# G1           3.0  19.0  10.91
# G2           0.0  19.0  10.71
# G3           0.0  20.0  10.42

# %%
import os

print("Inside notebooks:")
print(os.listdir("."))

print("\nInside notebooks/figures:")
if os.path.exists("figures"):
    print(os.listdir("figures"))
else:
    print("No figures folder found")
# Out:
# Inside notebooks:
# ['03_exploratory_data_analysis.ipynb', '01_data_understanding.ipynb', '.gitkeep', '02_data_cleaning_preprocessing.ipynb', 'figures', '00_environment.ipynb']
#
# Inside notebooks/figures:
# []

# %%
import matplotlib.pyplot as plt
import seaborn as sns
import os

os.makedirs("figures", exist_ok=True)

plt.figure(figsize=(8,5))
sns.histplot(df["G3"], bins=20, kde=True)

plt.title("Distribution of Final Grade (G3)")
plt.xlabel("G3")
plt.ylabel("Count")

plt.savefig("figures/grade_distribution.png", bbox_inches="tight", dpi=300)
plt.show()

print("Saved:", os.path.abspath("figures/grade_distribution.png"))
# Out:
# Saved: /Users/jjun28/Desktop/Github 2026/student-performance-prediction-ml/notebooks/figures/grade_distribution.png

# %%
import os
print(os.path.exists("figures/grade_distribution.png"))
# Out:
# True

# %% [markdown]
# # Session 14: Study Time and Performance Analysis

# %%
import os

print(os.getcwd())
# Out:
# /Users/jjun28/Desktop/Github 2026/student-performance-prediction-ml/notebooks

# %%
import os

print(os.listdir("."))
# Out:
# ['03_exploratory_data_analysis.ipynb', '01_data_understanding.ipynb', '.gitkeep', '02_data_cleaning_preprocessing.ipynb', 'figures', '00_environment.ipynb']

# %%
df = pd.read_csv("../data/student-mat.csv", sep=";")

# %%
import os
import matplotlib.pyplot as plt
import seaborn as sns

os.makedirs("figures", exist_ok=True)

mean_grades = (
    df.groupby("studytime")["G3"]
      .mean()
      .round(2)
)

print("Mean final grade by studytime:")
print(mean_grades)

plt.figure(figsize=(7,5))

sns.boxplot(
    x="studytime",
    y="G3",
    data=df
)

plt.title("Final Grade by Study Time")
plt.xlabel("Study Time Group")
plt.ylabel("Final Grade (G3)")

plt.savefig(
    "figures/studytime_vs_grade.png",
    dpi=300,
    bbox_inches="tight"
)

plt.show()
# Out:
# Mean final grade by studytime:
# studytime
# 1    10.05
# 2    10.17
# 3    11.40
# 4    11.26
# Name: G3, dtype: float64

# %% [markdown]
# ## Session 14 Findings
#
# Students with higher study-time levels generally tend to earn higher final grades.
#
# However, there is overlap between groups, suggesting that study time alone does not completely explain student performance.
#
# Study time may be useful as a predictor, but it should be combined with other variables such as absences and past failures.

# %% [markdown]
# # Session 15: Attendance, Failures, and Performance Analysis

# %%
import os
import matplotlib.pyplot as plt
import seaborn as sns

os.makedirs("figures", exist_ok=True)

print("Mean final grade by failures:")

failure_means = (
    df.groupby("failures")["G3"]
      .mean()
      .round(2)
)

print(failure_means)

plt.figure(figsize=(8,5))

sns.scatterplot(
    x="absences",
    y="G3",
    data=df,
    alpha=0.5
)

plt.title("Final Grade vs Absences")
plt.xlabel("Absences")
plt.ylabel("Final Grade (G3)")

plt.savefig(
    "figures/absences_vs_grade.png",
    dpi=300,
    bbox_inches="tight"
)

plt.show()
# Out:
# Mean final grade by failures:
# failures
# 0    11.25
# 1     8.12
# 2     6.24
# 3     5.69
# Name: G3, dtype: float64

# %% [markdown]
# # Session 16: Family and School Support Analysis

# %%
support_vars = ["schoolsup", "famsup", "higher"]

for var in support_vars:
    print("\n" + "="*50)
    print(f"Variable: {var}")

    summary = (
        df.groupby(var)["G3"]
          .agg(["count", "mean"])
          .round(2)
    )

    print(summary)
# Out:
# ...
# Variable: schoolsup
#            count   mean
# schoolsup
# no           344  10.56
# yes           51   9.43
#
# ...
# Variable: famsup
#         count   mean
# famsup
# no        153  10.64
# yes       242  10.27
#
# ...
# Variable: higher
#         count   mean
# higher
# no         20   6.80
# yes       375  10.61

# %% [markdown]
# # Session 17: Correlation Analysis

# %%
from pathlib import Path
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# Select numeric columns
numeric_df = df.select_dtypes(include="number").copy()

# Correlation matrix
corr = numeric_df.corr(method="pearson")

print("Correlation matrix shape:", corr.shape)

# Create figures directory
figures_dir = Path("figures")
figures_dir.mkdir(parents=True, exist_ok=True)

# Save path
output_path = figures_dir / "correlation_heatmap.png"

# Heatmap
plt.figure(figsize=(10, 8))

sns.heatmap(
    corr,
    annot=False,
    cmap="coolwarm",
    center=0,
    vmin=-1,
    vmax=1
)

plt.title("Correlation Heatmap")
plt.tight_layout()

plt.savefig(
    output_path,
    dpi=300,
    bbox_inches="tight"
)

plt.show()

print("Saved:", output_path)
# Out:
# Correlation matrix shape: (16, 16)
# Saved: figures/correlation_heatmap.png

# %%
g3_corr = (
    corr["G3"]
    .drop("G3")
    .sort_values(
        key=abs,
        ascending=False
    )
)

print(g3_corr.head(10))
# Out:
# G2            0.904868
# G1            0.801468
# failures     -0.360415
# Medu          0.217147
# age          -0.161579
# Fedu          0.152457
# goout        -0.132791
# traveltime   -0.117142
# studytime     0.097820
# health       -0.061335
# Name: G3, dtype: float64
